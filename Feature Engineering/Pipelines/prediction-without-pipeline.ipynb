# %%
import pandas as pd
import numpy as np

# %%
import pickle

# %% [markdown]
# ## Importing Models

# %%
clf = pickle.load(open('models-without-pipeline/clf.pkl','rb'))

# %%
age_imputer = pickle.load(open('models-without-pipeline/age_imputer.pkl','rb'))

# %%
ohe = pickle.load(open('models-without-pipeline/ohe.pkl','rb'))

# %% [markdown]
# ## Preparing Input

# %%
test_input = np.array([	3,	'male',	22.0,	0,	0,	7.25,	'S']).reshape(1,7)
test_input.shape
# Out:
# (1, 7)

# %%
test_input
# Out:
# array([['3', 'male', '22.0', '0', '0', '7.25', 'S']], dtype='<U32')

# %% [markdown]
# ## Using Models

# %%
test_input[:,[1,6]]
# Out:
# array([['male', 'S']], dtype='<U32')

# %%
ohe_sex_embarked = ohe.transform(test_input[:,[1,6]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
ohe.categories_
# Out:
# [array(['female', 'male'], dtype=object), array(['C', 'Q', 'S'], dtype=object)]

# %%
ohe_sex_embarked
# Out:
# array([[0., 1., 0., 0., 1.]])

# %%
test_input_age = test_input[:,2].reshape(1,1)

# %%
test_input
# Out:
# array([['3', 'male', '22.0', '0', '0', '7.25', 'S']], dtype='<U32')

# %% [markdown]
# ## Merging input

# %%
rem = test_input[:,[0,3,4,5]]
rem
# Out:
# array([['3', '0', '0', '7.25']], dtype='<U32')

# %%
test_input_transformed = np.concatenate((rem,ohe_sex_embarked,test_input_age),axis=1)
test_input_transformed
# Out:
# array([['3', '0', '0', '7.25', '0.0', '1.0', '0.0', '0.0', '1.0', '22.0']],
#       dtype='<U32')

# %%
test_input_transformed.shape
# Out:
# (1, 10)

# %% [markdown]
# ## Prediction

# %%
clf.predict(test_input_transformed)
# Out:
# array([0])
