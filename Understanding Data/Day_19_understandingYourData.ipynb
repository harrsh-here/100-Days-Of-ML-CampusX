# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tested.csv')

# %% [markdown]
# # How Big is the Data

# %%
df.shape
# Out:
# (418, 12)

# %% [markdown]
# # How does the data looks like

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# ### prints 5 random rows, to see unbiased rows if there is similar data on neighbour rows

# %%
df.sample(5) # by default it prints 1 , random row
# Out:
#      PassengerId  Survived  Pclass  \
# 251         1143         0       3
# 184         1076         1       1
# 28           920         0       1
# 385         1277         1       2
# 182         1074         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 251           Abrahamsson, Mr. Abraham August Johannes    male  20.0      0
# 184  Douglas, Mrs. Frederick Charles (Mary Helene B...  female  27.0      1
# 28                             Brady, Mr. John Bertram    male  41.0      0
# 385                                 Herman, Miss. Kate  female  24.0      1
# 182  Marvin, Mrs. Daniel Warner (Mary Graham Carmic...  female  18.0      1
#
#      Parch            Ticket      Fare    Cabin Embarked
# 251      0  SOTON/O2 3101284    7.9250      NaN        S
# 184      1          PC 17558  247.5208  B58 B60        C
# 28       0            113054   30.5000      A21        S
# 385      2            220845   65.0000      NaN        S
# ...

# %% [markdown]
# # What is the Data type of columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# # Are there any missing values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# # How does the data looks Mathematically

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %% [markdown]
# # Are there duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # How is Correlation between cols

# %% [markdown]
# #### This is used multiple times, as there are columns that may not have impact on each other
#  - this is PSM correlation ranges b/w 0-1
#  - if value is positive that means it is kind of proportional (correlated)
#  - if it is negative then it means that it is kind of inversly proportional (correlated)

# %%
df.corr( numeric_only = True) #
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.023245 -0.026751 -0.034102  0.003818  0.043080
# Survived       -0.023245  1.000000 -0.108615 -0.000013  0.099943  0.159120
# Pclass         -0.026751 -0.108615  1.000000 -0.492143  0.001087  0.018721
# Age            -0.034102 -0.000013 -0.492143  1.000000 -0.091587 -0.061249
# SibSp           0.003818  0.099943  0.001087 -0.091587  1.000000  0.306895
# Parch           0.043080  0.159120  0.018721 -0.061249  0.306895  1.000000
# Fare            0.008211  0.191514 -0.577147  0.337932  0.171539  0.230046
#
#                  Fare
# PassengerId  0.008211
# Survived     0.191514
# Pclass      -0.577147
# Age          0.337932
# SibSp        0.171539
# Parch        0.230046
# Fare         1.000000

# %% [markdown]
# #### if you want it for only target column

# %%
df.corr(numeric_only=True)[['Survived']]
# Out:
#              Survived
# PassengerId -0.023245
# Survived     1.000000
# Pclass      -0.108615
# Age         -0.000013
# SibSp        0.099943
# Parch        0.159120
# Fare         0.191514
